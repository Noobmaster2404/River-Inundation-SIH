# %%
import ee
ee.Authenticate()
ee.Initialize()

# %%
# Global Options for this notebook
SRTM = "CGIAR/SRTM90_V4"
L8_IR = "LANDSAT/LC08/C01/T1_SR"
L8 = "LANDSAT/LC08/C02/T1_TOA"

START_DATE = "2021-03-01"
END_DATE = "2021-05-31"
DISTRICT = "GORAKHPUR"
SCALE = 30

# %%
import geemap
table = ee.FeatureCollection("users/btech1044221/India_District_Shapefiles")
ROI = table.filter(ee.Filter.eq("District", DISTRICT))

# %%
training_points = ee.FeatureCollection(
        [ee.Feature(
            ee.Geometry.Point([83.7308991532113, 26.25297925928591]),
            {
              "LC": 0,
              "system:index": "0"
            }),
        ee.Feature(
            ee.Geometry.Point([83.74154215858239, 26.24651299195162]),
            {
              "LC": 0,
              "system:index": "1"
            }),
        ee.Feature(
            ee.Geometry.Point([83.75905161903161, 26.236658940275408]),
            {
              "LC": 0,
              "system:index": "2"
            }),
        ee.Feature(
            ee.Geometry.Point([83.73536234901208, 26.236658940275408]),
            {
              "LC": 0,
              "system:index": "3"
            }),
        ee.Feature(
            ee.Geometry.Point([83.7257493119027, 26.24959221175534]),
            {
              "LC": 0,
              "system:index": "4"
            }),
        ee.Feature(
            ee.Geometry.Point([83.74497538612145, 26.232347529978416]),
            {
              "LC": 0,
              "system:index": "5"
            }),
        ee.Feature(
            ee.Geometry.Point([83.78514414832848, 26.221260312300313]),
            {
              "LC": 0,
              "system:index": "6"
            }),
        ee.Feature(
            ee.Geometry.Point([83.79853373573083, 26.216640326349307]),
            {
              "LC": 0,
              "system:index": "7"
            }),
        ee.Feature(
            ee.Geometry.Point([83.80917674110192, 26.207091774082887]),
            {
              "LC": 0,
              "system:index": "8"
            }),
        ee.Feature(
            ee.Geometry.Point([83.81158000037927, 26.194769904045444]),
            {
              "LC": 0,
              "system:index": "9"
            }),
        ee.Feature(
            ee.Geometry.Point([83.82393961951989, 26.191689232807732]),
            {
              "LC": 0,
              "system:index": "10"
            }),
        ee.Feature(
            ee.Geometry.Point([83.81947642371911, 26.191689232807732]),
            {
              "LC": 0,
              "system:index": "11"
            }),
        ee.Feature(
            ee.Geometry.Point([83.82599955604333, 26.186759989356347]),
            {
              "LC": 0,
              "system:index": "12"
            }),
        ee.Feature(
            ee.Geometry.Point([83.84556895301598, 26.192613442734537]),
            {
              "LC": 0,
              "system:index": "13"
            }),
        ee.Feature(
            ee.Geometry.Point([83.85827189491052, 26.1886084800922]),
            {
              "LC": 0,
              "system:index": "14"
            }),
        ee.Feature(
            ee.Geometry.Point([83.86239176795739, 26.186759989356347]),
            {
              "LC": 0,
              "system:index": "15"
            }),
        ee.Feature(
            ee.Geometry.Point([83.52806159816642, 26.276744768107694]),
            {
              "LC": 0,
              "system:index": "16"
            }),
        ee.Feature(
            ee.Geometry.Point([83.5215384658422, 26.277514380320284]),
            {
              "LC": 0,
              "system:index": "17"
            }),
        ee.Feature(
            ee.Geometry.Point([83.53424140773673, 26.277360458286086]),
            {
              "LC": 0,
              "system:index": "18"
            }),
        ee.Feature(
            ee.Geometry.Point([83.507633894309, 26.278130066415383]),
            {
              "LC": 0,
              "system:index": "19"
            }),
        ee.Feature(
            ee.Geometry.Point([83.57080528102775, 26.262890875600494]),
            {
              "LC": 0,
              "system:index": "20"
            }),
        ee.Feature(
            ee.Geometry.Point([83.56514045558829, 26.262429050710463]),
            {
              "LC": 0,
              "system:index": "21"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55501243434806, 26.264430278635018]),
            {
              "LC": 0,
              "system:index": "22"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55827400051017, 26.264430278635018]),
            {
              "LC": 0,
              "system:index": "23"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55072089992423, 26.271049479109543]),
            {
              "LC": 0,
              "system:index": "24"
            }),
        ee.Feature(
            ee.Geometry.Point([83.5438544448461, 26.271665199501527]),
            {
              "LC": 0,
              "system:index": "25"
            }),
        ee.Feature(
            ee.Geometry.Point([83.53355476222892, 26.276436921793547]),
            {
              "LC": 0,
              "system:index": "26"
            }),
        ee.Feature(
            ee.Geometry.Point([83.57492515407462, 26.261505395420212]),
            {
              "LC": 0,
              "system:index": "27"
            }),
        ee.Feature(
            ee.Geometry.Point([83.58093330226798, 26.25996595361043]),
            {
              "LC": 0,
              "system:index": "28"
            }),
        ee.Feature(
            ee.Geometry.Point([83.42901298366446, 26.26366057966885]),
            {
              "LC": 0,
              "system:index": "29"
            }),
        ee.Feature(
            ee.Geometry.Point([83.44429084621329, 26.265815723916187]),
            {
              "LC": 0,
              "system:index": "30"
            }),
        ee.Feature(
            ee.Geometry.Point([83.45613548122306, 26.264276339249953]),
            {
              "LC": 0,
              "system:index": "31"
            }),
        ee.Feature(
            ee.Geometry.Point([83.46180030666251, 26.264122399660824]),
            {
              "LC": 0,
              "system:index": "32"
            }),
        ee.Feature(
            ee.Geometry.Point([83.4720999892797, 26.26366057966885]),
            {
              "LC": 0,
              "system:index": "33"
            }),
        ee.Feature(
            ee.Geometry.Point([83.48154136501212, 26.261197508690838]),
            {
              "LC": 0,
              "system:index": "34"
            }),
        ee.Feature(
            ee.Geometry.Point([83.48789283595939, 26.256579109798146]),
            {
              "LC": 0,
              "system:index": "35"
            }),
        ee.Feature(
            ee.Geometry.Point([83.50128242336173, 26.272280916627363]),
            {
              "LC": 0,
              "system:index": "36"
            }),
        ee.Feature(
            ee.Geometry.Point([83.50420066676993, 26.276282998330238]),
            {
              "LC": 0,
              "system:index": "37"
            }),
        ee.Feature(
            ee.Geometry.Point([83.60635323726599, 26.34657648633489]),
            {
              "LC": 0,
              "system:index": "38"
            }),
        ee.Feature(
            ee.Geometry.Point([83.60970063411658, 26.346268825494793]),
            {
              "LC": 0,
              "system:index": "39"
            }),
        ee.Feature(
            ee.Geometry.Point([83.62154526912634, 26.338961640096887]),
            {
              "LC": 0,
              "system:index": "40"
            }),
        ee.Feature(
            ee.Geometry.Point([83.62223191463416, 26.336423246662925]),
            {
              "LC": 0,
              "system:index": "41"
            }),
        ee.Feature(
            ee.Geometry.Point([83.62248940669959, 26.33534633565972]),
            {
              "LC": 0,
              "system:index": "42"
            }),
        ee.Feature(
            ee.Geometry.Point([83.62300439083045, 26.332577089930112]),
            {
              "LC": 0,
              "system:index": "43"
            }),
        ee.Feature(
            ee.Geometry.Point([83.62283272945349, 26.32696147161846]),
            {
              "LC": 0,
              "system:index": "44"
            }),
        ee.Feature(
            ee.Geometry.Point([83.52367445738088, 26.393582348213513]),
            {
              "LC": 0,
              "system:index": "45"
            }),
        ee.Feature(
            ee.Geometry.Point([83.5256056478716, 26.395120014597985]),
            {
              "LC": 0,
              "system:index": "46"
            }),
        ee.Feature(
            ee.Geometry.Point([83.51408505265763, 26.384222700599267]),
            {
              "LC": 0,
              "system:index": "47"
            }),
        ee.Feature(
            ee.Geometry.Point([83.49080971863202, 26.46131963043785]),
            {
              "LC": 0,
              "system:index": "48"
            }),
        ee.Feature(
            ee.Geometry.Point([83.49261216309003, 26.46131963043785]),
            {
              "LC": 0,
              "system:index": "49"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55732850220136, 26.447065174892625]),
            {
              "LC": 0,
              "system:index": "50"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55230740692548, 26.45551816471291]),
            {
              "LC": 0,
              "system:index": "51"
            }),
        ee.Feature(
            ee.Geometry.Point([83.56011799957685, 26.45386603821475]),
            {
              "LC": 0,
              "system:index": "52"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55556897308759, 26.454711315198576]),
            {
              "LC": 0,
              "system:index": "53"
            }),
        ee.Feature(
            ee.Geometry.Point([83.53599957611493, 26.455095529958143]),
            {
              "LC": 0,
              "system:index": "54"
            }),
        ee.Feature(
            ee.Geometry.Point([83.31421321552276, 26.461627061598314]),
            {
              "LC": 1,
              "system:index": "0"
            }),
        ee.Feature(
            ee.Geometry.Point([83.33549922626494, 26.45486507815354]),
            {
              "LC": 1,
              "system:index": "1"
            }),
        ee.Feature(
            ee.Geometry.Point([83.34305232685088, 26.449024863768496]),
            {
              "LC": 1,
              "system:index": "2"
            }),
        ee.Feature(
            ee.Geometry.Point([83.3660549513626, 26.41213245908996]),
            {
              "LC": 1,
              "system:index": "3"
            }),
        ee.Feature(
            ee.Geometry.Point([83.52364009540557, 26.427813173807454]),
            {
              "LC": 1,
              "system:index": "4"
            }),
        ee.Feature(
            ee.Geometry.Point([83.71075099628447, 26.426583390891096]),
            {
              "LC": 1,
              "system:index": "5"
            }),
        ee.Feature(
            ee.Geometry.Point([83.74988979022979, 26.4345767453372]),
            {
              "LC": 1,
              "system:index": "6"
            }),
        ee.Feature(
            ee.Geometry.Point([83.67676204364776, 26.43918804381454]),
            {
              "LC": 1,
              "system:index": "7"
            }),
        ee.Feature(
            ee.Geometry.Point([83.66989558856963, 26.437650964825284]),
            {
              "LC": 1,
              "system:index": "8"
            }),
        ee.Feature(
            ee.Geometry.Point([83.68843501728057, 26.432732174280478]),
            {
              "LC": 1,
              "system:index": "9"
            }),
        ee.Feature(
            ee.Geometry.Point([83.71040767353057, 26.45517244965331]),
            {
              "LC": 1,
              "system:index": "10"
            }),
        ee.Feature(
            ee.Geometry.Point([82.92488521259307, 26.345081070135205]),
            {
              "LC": 1,
              "system:index": "11"
            }),
        ee.Feature(
            ee.Geometry.Point([82.96196407001494, 26.30692439594269]),
            {
              "LC": 1,
              "system:index": "12"
            }),
        ee.Feature(
            ee.Geometry.Point([83.13911861103057, 26.2872257109509]),
            {
              "LC": 1,
              "system:index": "13"
            }),
        ee.Feature(
            ee.Geometry.Point([83.20915645282744, 26.297075471793004]),
            {
              "LC": 1,
              "system:index": "14"
            }),
        ee.Feature(
            ee.Geometry.Point([83.1734508864212, 26.336466146038717]),
            {
              "LC": 1,
              "system:index": "15"
            }),
        ee.Feature(
            ee.Geometry.Point([83.1734508864212, 26.304462243357193]),
            {
              "LC": 1,
              "system:index": "16"
            }),
        ee.Feature(
            ee.Geometry.Point([83.18169063251494, 26.54673257235642]),
            {
              "LC": 1,
              "system:index": "17"
            }),
        ee.Feature(
            ee.Geometry.Point([83.2723278395462, 26.56761525744034]),
            {
              "LC": 1,
              "system:index": "18"
            }),
        ee.Feature(
            ee.Geometry.Point([83.22014278095244, 26.608141369611037]),
            {
              "LC": 1,
              "system:index": "19"
            }),
        ee.Feature(
            ee.Geometry.Point([83.81477779071807, 26.353695352819077]),
            {
              "LC": 1,
              "system:index": "20"
            }),
        ee.Feature(
            ee.Geometry.Point([83.87382930438994, 26.377073742839734]),
            {
              "LC": 1,
              "system:index": "21"
            }),
        ee.Feature(
            ee.Geometry.Point([83.8161510817337, 26.2872257109509]),
            {
              "LC": 1,
              "system:index": "22"
            }),
        ee.Feature(
            ee.Geometry.Point([83.94787270407404, 26.302014299466038]),
            {
              "LC": 1,
              "system:index": "23"
            }),
        ee.Feature(
            ee.Geometry.Point([83.93276650290217, 26.291549346542716]),
            {
              "LC": 1,
              "system:index": "24"
            }),
        ee.Feature(
            ee.Geometry.Point([83.91491371969904, 26.342633984691403]),
            {
              "LC": 1,
              "system:index": "25"
            }),
        ee.Feature(
            ee.Geometry.Point([83.88058144430842, 26.2884712394689]),
            {
              "LC": 1,
              "system:index": "26"
            }),
        ee.Feature(
            ee.Geometry.Point([83.84418923239436, 26.31555577738308]),
            {
              "LC": 1,
              "system:index": "27"
            }),
        ee.Feature(
            ee.Geometry.Point([83.69038063864436, 26.38077888661042]),
            {
              "LC": 1,
              "system:index": "28"
            }),
        ee.Feature(
            ee.Geometry.Point([83.7144132314178, 26.358631766054806]),
            {
              "LC": 1,
              "system:index": "29"
            }),
        ee.Feature(
            ee.Geometry.Point([83.75423867087092, 26.383239415779403]),
            {
              "LC": 1,
              "system:index": "30"
            }),
        ee.Feature(
            ee.Geometry.Point([83.8077970204803, 26.39492621350448]),
            {
              "LC": 1,
              "system:index": "31"
            }),
        ee.Feature(
            ee.Geometry.Point([83.4074826894256, 26.37708799458942]),
            {
              "LC": 1,
              "system:index": "32"
            }),
        ee.Feature(
            ee.Geometry.Point([83.43769509176936, 26.35617071294091]),
            {
              "LC": 1,
              "system:index": "33"
            }),
        ee.Feature(
            ee.Geometry.Point([83.33263832907404, 26.293396171573278]),
            {
              "LC": 1,
              "system:index": "34"
            }),
        ee.Feature(
            ee.Geometry.Point([83.29006630758967, 26.26938515256208]),
            {
              "LC": 1,
              "system:index": "35"
            }),
        ee.Feature(
            ee.Geometry.Point([83.23582131247248, 26.26384344262164]),
            {
              "LC": 1,
              "system:index": "36"
            }),
        ee.Feature(
            ee.Geometry.Point([83.14175087790217, 26.27923642813747]),
            {
              "LC": 1,
              "system:index": "37"
            }),
        ee.Feature(
            ee.Geometry.Point([83.04081398825373, 26.29893647018665]),
            {
              "LC": 1,
              "system:index": "38"
            }),
        ee.Feature(
            ee.Geometry.Point([82.99686867575373, 26.401691713636325]),
            {
              "LC": 1,
              "system:index": "39"
            }),
        ee.Feature(
            ee.Geometry.Point([83.02914101462092, 26.35494016674285]),
            {
              "LC": 1,
              "system:index": "40"
            }),
        ee.Feature(
            ee.Geometry.Point([83.5228391347381, 26.35494016674285]),
            {
              "LC": 1,
              "system:index": "41"
            }),
        ee.Feature(
            ee.Geometry.Point([83.55167824606623, 26.330326493719827]),
            {
              "LC": 1,
              "system:index": "42"
            })]
)

# %%
geometry = ee.Geometry.MultiPoint(
        [[83.23658088148656, 26.802690642697854],
         [83.36155036390844, 26.837006476244376],
         [83.49338630140844, 26.757328790922866],
         [83.40549567640844, 26.66286904763994],
         [83.28189948500219, 26.69845399258321],
         [83.31348517836156, 26.789206580232257],
         [83.39725593031469, 26.786754760334347],
         [83.34760354751187, 26.73136393803767],
         [83.34726022475796, 26.726457748478765],
         [83.34108041518765, 26.70407057460504],
         [83.35584329360562, 26.702537045456538],
         [83.17550662191962, 26.815274127222878],
         [83.14254763754462, 26.792597982846132],
         [83.20228579672431, 26.836720359726932],
         [83.18649295004462, 26.78646851696478],
         [83.16452029379462, 26.845910359298582],
         [83.17936760495814, 26.57702219877475],
         [83.24597221921596, 26.604038981375403],
         [83.26313835691127, 26.55552702401718],
         [83.30159050534877, 26.51375344805587],
         [83.22331291745814, 26.524198267672823],
         [83.18348747800502, 26.64148351339881],
         [83.39291435788783, 26.51129570537058],
         [83.34965569089564, 26.48487165076091],
         [83.22811943601283, 26.467047347295257],
         [83.42106682370814, 26.489173655022867],
         [83.16143886182596, 26.45375603985706],
         [83.55488673780252, 26.313507899860255],
         [83.40176478956033, 26.371965318004932],
         [83.35713283155252, 26.42424427246682],
         [83.32005397413064, 26.397185181392633],
         [83.4113778266697, 26.32827887735718],
         [83.43541041944314, 26.405795580584915],
         [83.47248927686502, 26.352277696975516],
         [83.58235255811502, 26.28765415779587],
         [83.59883205030252, 26.3202781650458],
         [83.56312648389627, 26.277187909033128],
         [83.59127894971658, 26.277187909033128],
         [83.64071742627908, 26.28765415779587],
         [83.60707179639627, 26.261794651848486],
         [83.21637050245096, 26.43285265204655],
         [83.21568385694314, 26.46174750914507],
         [83.18890468213846, 26.474040993967563],
         [83.32486049268533, 26.491249665973044],
         [83.2568825874119, 26.491249665973044],
         [83.24177638624002, 26.507226840938994],
         [83.11543361280252, 26.463591615586243],
         [83.13259975049783, 26.41625020160635],
         [83.13946620557596, 26.450067482338184],
         [83.13877956006814, 26.469738423666538],
         [83.37704555127908, 26.397800231208883],
         [83.37086574170877, 26.357815179235708],
         [83.43609706495096, 26.35535410874285],
         [83.41755763624002, 26.45068225012906],
         [83.36537257764627, 26.49800951107974],
         [83.2942921900543, 26.60276996409572],
         [83.3272511744293, 26.616276113419246],
         [83.31489155528868, 26.57943740495302],
         [83.58405659435118, 26.634691018799618],
         [83.47831318614806, 26.700960094569876],
         [83.49341938731993, 26.736533145090664],
         [83.4206349634918, 26.82112773913459],
         [83.4645802759918, 26.81499981507918],
         [83.29703877208556, 26.878714021729024],
         [83.2887990259918, 26.838284163540884],
         [83.2668263697418, 26.818676609271524],
         [83.2723195338043, 26.80151721606216],
         [83.2064015650543, 26.789258916881558]])

# %%
# How to export an asset
export_params = {
    'collection': 'name_of_collection_to_export',  # The feature collection to export
    'description': 'sampled_data',  # The name of the output file
    'folder': 'sih',  # The folder in your Google Drive where the file will be saved
    'fileFormat': 'GeoJSON'  # The export format (GeoJSON in this case)
}

# Start export
task = ee.batch.Export.table.toDrive(**export_params)
task.start()

# %%
# For Digital Elevation Model
visParams = {
    "min": 69,
    "max": 104
}
dataset = ee.Image(SRTM).select("elevation").clip(ROI)

Map = geemap.Map()
Map.addLayer(dataset, visParams, "DEM")
Map

# %%
# For IR
visParams = {
  "bands": ["B5", "B6", "B10"],
	"min": 0,
	"max": 3000,
	"gamma": 1.2,
}
selection = ee.ImageCollection(L8_IR).filterDate(START_DATE, END_DATE).clip(ROI).filter(ee.Filter.lt("CLOUD_COVER", 10)).median()

Map = geemap.Map()
Map.addLayer(selection, visParams, "IR")
Map

# %%
# For image classification using CART classifier
# Just a visual of what the actual flood extent is
selection_l8 = ee.ImageCollection(L8).filterBounds(ROI).filterDate(START_DATE, END_DATE).filterMetadata("CLOUD_COVER", "less_than", 1).mean()

training_data = selection_l8.sampleRegions(**{'collection':training_points, 'properties':["LC"], 'scale': 30})
classifier = ee.Classifier.smileCart();
classifier = classifier.train(**{
	"features": training_data,
	"classProperty": "LC",
	"inputProperties": [
		"B1",
		"B2",
		"B3",
		"B4",
		"B5",
		"B6",
		"B7",
    "B8",
    "B9",
		"B10",
		"B11",
	],
});

classified_image = selection_l8.classify(classifier);
classificationParams = {"opacity": 1, "bands": ["classification"],"min": 0,"max": 2,"palette": ["2874ed","30e026"]}
Map.addLayer(classified_image, classificationParams, "classifier");
Map

# %%
# For exporting the DEM data
selection_dem = ee.Image(SRTM).clip(ROI)
dem_bands = selection_dem.select(["elevation"]).rename(["dem_0"])

dem_data = dem_bands.sample(**{"region": geometry, "scale": SCALE, "geometries": True})

export_params = {
    'collection': dem_data,  # The feature collection to export
    'description': 'dem_bands_data_mod_2',  # The name of the output file
    'folder': 'sih',  # The folder in your Google Drive where the file will be saved
    'fileFormat': 'CSV'  # The export format (CSV in this case)
}

# Start export
task = ee.batch.Export.table.toDrive(**export_params)
task.start()

# %%
# For exporting the NIR/SWIR band data
selection_ir = ee.ImageCollection(L8_IR).filterDate(START_DATE, END_DATE).filterBounds(ROI).filter(ee.Filter.lt("CLOUD_COVER", 10)).median()
ir_bands = selection_ir.select(["B5", "B6", "B10"]).rename(["ir_0", "ir_1", "ir_2"])

ir_data = ir_bands.sample(**{"region": geometry, "scale": SCALE, "geometries": True})

export_params = {
    'collection': ir_data,  # The feature collection to export
    'description': 'ir_bands_data_mod_2',  # The name of the output file
    'folder': 'sih',  # The folder in your Google Drive where the file will be saved
    'fileFormat': 'CSV'  # The export format (CSV in this case)
}

# Start export
task = ee.batch.Export.table.toDrive(**export_params)
task.start()

# %%
# Trying to combine the "elevation" band of SRTM and "B5", "B6", "B10" bands of L8
# I don't think this works properly yet
selection_dem = ee.Image(SRTM).clip(ROI)
selection_ir = ee.ImageCollection(L8_IR).filterDate(START_DATE, END_DATE).filter(ee.Filter.lt("CLOUD_COVER", 10)).median().clip(ROI)

dem_bands = selection_dem.select(["elevation"]).rename(["dem_0"])
ir_bands = selection_ir.select(["B5", "B6", "B10"]).rename(["ir_0", "ir_1", "ir_2"])

img = ir_bands.addBands(dem_bands)
data = img.sample(**{"region": geometry, "scale": SCALE, "geometries": True})

export_params = {
    'collection': data,  # The feature collection to export
    'description': 'combined_data_1',  # The name of the output file
    'folder': 'sih',  # The folder in your Google Drive where the file will be saved
    'fileFormat': 'CSV'  # The export format (CSV in this case)
}

# Start export
task = ee.batch.Export.table.toDrive(**export_params)
task.start()
